# %%
import pandas as pd

# %%
poke_df = pd.read_csv('./pokemon_data.csv')
poke_df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
poke_df[['Name','Type 1','Legendary']]
# Out:
#                       Name   Type 1  Legendary
# 0                Bulbasaur    Grass      False
# 1                  Ivysaur    Grass      False
# 2                 Venusaur    Grass      False
# 3    VenusaurMega Venusaur    Grass      False
# 4               Charmander     Fire      False
# ..                     ...      ...        ...
# 795                Diancie     Rock       True
# 796    DiancieMega Diancie     Rock       True
# 797    HoopaHoopa Confined  Psychic       True
# 798     HoopaHoopa Unbound  Psychic       True
# 799              Volcanion     Fire       True
#
# [800 rows x 3 columns]

# %%
poke_df.iloc[:,[1,2,-1]]
# Out:
#                       Name   Type 1  Legendary
# 0                Bulbasaur    Grass      False
# 1                  Ivysaur    Grass      False
# 2                 Venusaur    Grass      False
# 3    VenusaurMega Venusaur    Grass      False
# 4               Charmander     Fire      False
# ..                     ...      ...        ...
# 795                Diancie     Rock       True
# 796    DiancieMega Diancie     Rock       True
# 797    HoopaHoopa Confined  Psychic       True
# 798     HoopaHoopa Unbound  Psychic       True
# 799              Volcanion     Fire       True
#
# [800 rows x 3 columns]

# %%
len(poke_df.loc[poke_df['Legendary']==True])
poke_df.loc[poke_df['Legendary']==True]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#sorting by legendary and higest attack 
poke_df.sort_values(['Legendary','Attack'],ascending=[0,0])
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386     DeoxysAttack Forme  Psychic       NaN   50     180       20
# 711  646     KyuremBlack Kyurem   Dragon       Ice  125     170      100
# ..   ...                    ...      ...       ...  ...     ...      ...
# 139  129               Magikarp    Water       NaN   20      10       55
# 230  213                Shuckle      Bug      Rock   20      10      230
# 261  242                Blissey   Normal       NaN  255      10       10
# 121  113                Chansey   Normal       NaN  250       5        5
# 488  440                Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke_df['Total'] = poke_df.iloc[:, 4:10].sum(axis=1)
poke_df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
cols = poke_df.columns.tolist()
test_df = poke_df[cols[0:10]+[cols[-1]]+cols[10:12]]
test_df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1      False

# %%
poke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
#  12  Total       800 non-null    int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
#sorting grass and flying based on legendary
new_df =poke_df.loc[(poke_df['Type 1']=='Grass') & 
                    (poke_df["Type 2"] == 'Flying')].sort_values(['Legendary'],ascending=0)

new_df.reset_index(drop=True, inplace=True)

# %%
import re 

poke_df.loc[~poke_df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
poke_df.groupby(['Type 1']).mean(numeric_only=True).sort_values(['Total'],ascending=0)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# ...

# %%
poke_df['Type 1'].value_counts(ascending=True)
# Out:
# Type 1
# Flying        4
# Fairy        17
# Ice          24
# Steel        27
# Fighting     27
# Poison       28
# Dark         31
# Ground       32
# Ghost        32
# Dragon       32
# Electric     44
# Rock         44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: count, dtype: int64

# %%
new_df = pd.DataFrame(columns=poke_df.columns)

for df in pd.read_csv('/pokemon_data.csv',chunksize=10):
